# %%
import numpy as np
import pandas as pd

data = pd.read_csv('201702_user_rawdata.tsv')
data.head()
# Out:
#         uid  ltv  amount  rank  max_rarity_chara_num  max_skill_num  \
# 0  12745343    0       0    49                     0             12
# 1  21126878    0       0     2                     0              0
# 2  16351035    0       0    33                     0              1
# 3   9083641    0       0    28                     0              0
# 4  23406395    0       0     9                     0              0
#
#    multi_battle_num
# 0               105
# 1                 0
# 2                 5
# 3                 0
# 4                 8

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data.loc[data.ltv>1e6,'ltv'] = 1e6
data.loc[data.amount>2e5,'amount'] = 2e5

sns.set(style='whitegrid', context='notebook')
cols = ['ltv','amount','rank','max_skill_num','multi_battle_num']
sns.pairplot(data[cols], size=3)
plt.show()

# %%
data.loc[data.ltv>1e6,'ltv'] = 1e6



#data_new = pd.merge(data, ltv, how="inner", left_on="Store", right_on="Store")
data.head()
# Out:
#         uid  ltv  amount  rank  max_rarity_chara_num  max_skill_num  \
# 0  12745343  0.0       0    49                     0             12
# 1  21126878  0.0       0     2                     0              0
# 2  16351035  0.0       0    33                     0              1
# 3   9083641  0.0       0    28                     0              0
# 4  23406395  0.0       0     9                     0              0
#
#    multi_battle_num
# 0               105
# 1                 0
# 2                 5
# 3                 0
# 4                 8

# %%
data_gcc = pd.read_csv('201703_gcc.tsv')
data_gcc.head()
# Out:
#    mobage_user_id  rank        sales     activity
# 0           42203    14   466.666667   479.333333
# 1          156217     7   566.666667     0.333333
# 2          171479    15   900.000000  1395.000000
# 3          197858     8   833.333333    45.333333
# 4          343659     7  1666.666667   167.666667

# %%
cols = ['rank','sales','activity']
sns.pairplot(data_gcc[cols], size=3)
plt.show()
